# %% [markdown]
# ## Análise e Previsão de Produtividade de Culturas com Base em Clima e Tendências Técnicas

# %% [markdown]
# Objetivo: Investigar como fatores climáticos (chuva, temperatura média, extremos) e eventos técnicos (ex: introdução de sementes transgênicas ou novas práticas) influenciaram a produtividade das grandes culturas no Brasil nas últimas décadas.
#
# Perguntas de negócio:
#
# - Há uma correlação clara entre clima e produtividade?
# - Quais culturas são mais sensíveis a extremos climáticos?
# - Quando os saltos de produtividade ocorreram, houve relação com tecnologia ou clima favorável?
#
# Fontes de dados:
#
# - Produção agrícola por cultura e estado: IBGE – PAM
# - Clima histórico: INMET (ou NOAA/ERA5 para dados globais diários)
# - Eventos técnicos: você pode simular ou anotar marcos com base em artigos ou estudos (ex: “adoção de soja transgênica em 2005”)
#
# Entregáveis:
#
# - Dashboard exploratório com visualizações interativas por cultura, região, ano
# - Análise descritiva e gráfica de correlações
# - Mapa de calor ou gráfico de dispersão mostrando padrões regionais

# %%
import requests
import pandas as pd
import time
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import geopandas as gpd
from ipywidgets import widgets
from IPython.display import display
import plotly.graph_objects as go

# %%
import geobr
# Gerar dados geograficos para mapas
#municipalities = geobr.read_municipality()
#municipalities=municipalities.rename({"name_muni": "Municipio",'abbrev_state':"Estado"}, axis=1)
#municipalities['Muni_Estado'] = municipalities['Municipio'] + ' - ' + municipalities['Estado']

# Load and prepare data
regions = geobr.read_meso_region()
regions['Mesorregião'] = regions['name_meso'] + ' - ' + regions['abbrev_state']
regions = gpd.GeoDataFrame(regions[['Mesorregião','geometry']])

# Better simplification
regions['geometry'] = regions.simplify(tolerance=0.01, preserve_topology=False)

# Round coordinates to reduce precision (fewer decimal places)
regions = regions.round(3)

# Remove small polygons
min_area = 0.001  # Adjust based on your data
regions['geometry'] = regions.geometry.apply(
    lambda geom: geom if geom.area > min_area else None
)

# Save with optimized settings
#regions.to_file("meso_region.geojson", driver='GeoJSON', encoding='utf-8')
# Para criar mapas no Power BI
'''
import topojson
regions_dissolved = regions.dissolve(by='Mesorregião').reset_index()
regions_topo = topojson.Topology(regions_dissolved, prequantize=False)
with open("regions.topojson", "w") as f:
    f.write(regions_topo.to_json())
'''
# Out:
# '\nimport topojson\nregions_dissolved = regions.dissolve(by=\'Mesorregião\').reset_index()\nregions_topo = topojson.Topology(regions_dissolved, prequantize=False)\nwith open("regions.topojson", "w") as f:\n    f.write(regions_topo.to_json())\n'

# %% [markdown]
# Coleta e processamento de dados a nível de mesorregião

# %%
# Configurações
BASE_URL = 'https://apisidra.ibge.gov.br/values'
TABELA = '1612'  # Tabela de produção agrícola municipal
NIVEL = '8'      # Nível 8 = Mesorregião

# Produtos desejados (códigos da classificação 81)
PRODUTOS = ['2713', '2711', '2702', '2716', '2692', '2696']
PRODUTOS_NOMES = {
    '2713': 'Soja (em grão)',
    '2711': 'Milho (em grão)',
    '2702': 'Feijão (em grão)',
    '2716': 'Trigo (em grão)',
    '2692': 'Arroz (em casca)',
    '2696': 'Cana-de-açúcar',
    
}

# Função para obter dados de uma variável e produto específico para todas as mesorregiões
def obter_dados(produto, ano):
    # Usando a mesma estrutura de URL que foi comprovada como funcional
    url = f"{BASE_URL}/t/{TABELA}/n{NIVEL}/all/p/{ano}/c81/{produto}/f/u"
    print(f"Obtendo dados: produto={produto}, ano={ano}")
    print(f"URL: {url}")
    
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            if len(data) <= 1:  # Só tem o cabeçalho
                print(f"Sem dados para: produto={produto}, ano={ano}")
                return None
            
            # Converte para DataFrame
            df = pd.DataFrame(data[1:])  # Pula o cabeçalho
            
            print(f"Obtidos {len(df)} registros")
            return df
        else:
            print(f"Erro na requisição: {response.status_code}, {response.text}")
            return None
    except Exception as e:
        print(f"Erro ao obter dados: {str(e)}")
        return None


print("Iniciando coleta de dados da API do SIDRA/IBGE...")
# Lista para armazenar todos os dataframes
dataframes = []

# Para cada combinação de parâmetros
total_combinacoes = len(PRODUTOS) * (2023-1994)
combinacoes_processadas = 0

for ano in range(1994, 2024):
    for produto in PRODUTOS:
        # Adiciona um pequeno delay para evitar sobrecarregar a API
        time.sleep(0.3)
        
        df = obter_dados(produto, ano)
        if df is not None:
            dataframes.append(df)
        
        # Atualiza o progresso
        combinacoes_processadas += 1
        progresso = (combinacoes_processadas / total_combinacoes) * 100
        print(f"Progresso: {progresso:.1f}% ({combinacoes_processadas}/{total_combinacoes})")

# Verifica se obteve algum dado
if not dataframes:
    print("Nenhum dado foi obtido. Saindo.")

# Concatena todos os dataframes
print("Unindo todos os dados...")
resultado = pd.concat(dataframes, ignore_index=True)

# Salva o resultado em CSV
arquivo_saida = 'producao_agricola_mesorregiao.parquet'
resultado.to_parquet(arquivo_saida, index=False)
print(f"Dados salvos em: {arquivo_saida}")

print("Processamento concluído!")
# Out:
# Iniciando coleta de dados da API do SIDRA/IBGE...
# Obtendo dados: produto=2713, ano=1994
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1994/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -0.6% (1/-174)
# Obtendo dados: produto=2711, ano=1994
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1994/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -1.1% (2/-174)
# Obtendo dados: produto=2702, ano=1994
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1994/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -1.7% (3/-174)
# Obtendo dados: produto=2716, ano=1994
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1994/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -2.3% (4/-174)
# Obtendo dados: produto=2692, ano=1994
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1994/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -2.9% (5/-174)
# Obtendo dados: produto=2696, ano=1994
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1994/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -3.4% (6/-174)
# Obtendo dados: produto=2713, ano=1995
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1995/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -4.0% (7/-174)
# Obtendo dados: produto=2711, ano=1995
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1995/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -4.6% (8/-174)
# Obtendo dados: produto=2702, ano=1995
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1995/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -5.2% (9/-174)
# Obtendo dados: produto=2716, ano=1995
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1995/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -5.7% (10/-174)
# Obtendo dados: produto=2692, ano=1995
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1995/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -6.3% (11/-174)
# Obtendo dados: produto=2696, ano=1995
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1995/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -6.9% (12/-174)
# Obtendo dados: produto=2713, ano=1996
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1996/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -7.5% (13/-174)
# Obtendo dados: produto=2711, ano=1996
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1996/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -8.0% (14/-174)
# Obtendo dados: produto=2702, ano=1996
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1996/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -8.6% (15/-174)
# Obtendo dados: produto=2716, ano=1996
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1996/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -9.2% (16/-174)
# Obtendo dados: produto=2692, ano=1996
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1996/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -9.8% (17/-174)
# Obtendo dados: produto=2696, ano=1996
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1996/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -10.3% (18/-174)
# Obtendo dados: produto=2713, ano=1997
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1997/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -10.9% (19/-174)
# Obtendo dados: produto=2711, ano=1997
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1997/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -11.5% (20/-174)
# Obtendo dados: produto=2702, ano=1997
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1997/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -12.1% (21/-174)
# Obtendo dados: produto=2716, ano=1997
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1997/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -12.6% (22/-174)
# Obtendo dados: produto=2692, ano=1997
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1997/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -13.2% (23/-174)
# Obtendo dados: produto=2696, ano=1997
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1997/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -13.8% (24/-174)
# Obtendo dados: produto=2713, ano=1998
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1998/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -14.4% (25/-174)
# Obtendo dados: produto=2711, ano=1998
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1998/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -14.9% (26/-174)
# Obtendo dados: produto=2702, ano=1998
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1998/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -15.5% (27/-174)
# Obtendo dados: produto=2716, ano=1998
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1998/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -16.1% (28/-174)
# Obtendo dados: produto=2692, ano=1998
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1998/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -16.7% (29/-174)
# Obtendo dados: produto=2696, ano=1998
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1998/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -17.2% (30/-174)
# Obtendo dados: produto=2713, ano=1999
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1999/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -17.8% (31/-174)
# Obtendo dados: produto=2711, ano=1999
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1999/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -18.4% (32/-174)
# Obtendo dados: produto=2702, ano=1999
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1999/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -19.0% (33/-174)
# Obtendo dados: produto=2716, ano=1999
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1999/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -19.5% (34/-174)
# Obtendo dados: produto=2692, ano=1999
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1999/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -20.1% (35/-174)
# Obtendo dados: produto=2696, ano=1999
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/1999/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -20.7% (36/-174)
# Obtendo dados: produto=2713, ano=2000
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2000/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -21.3% (37/-174)
# Obtendo dados: produto=2711, ano=2000
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2000/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -21.8% (38/-174)
# Obtendo dados: produto=2702, ano=2000
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2000/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -22.4% (39/-174)
# Obtendo dados: produto=2716, ano=2000
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2000/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -23.0% (40/-174)
# Obtendo dados: produto=2692, ano=2000
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2000/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -23.6% (41/-174)
# Obtendo dados: produto=2696, ano=2000
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2000/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -24.1% (42/-174)
# Obtendo dados: produto=2713, ano=2001
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2001/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -24.7% (43/-174)
# Obtendo dados: produto=2711, ano=2001
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2001/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -25.3% (44/-174)
# Obtendo dados: produto=2702, ano=2001
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2001/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -25.9% (45/-174)
# Obtendo dados: produto=2716, ano=2001
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2001/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -26.4% (46/-174)
# Obtendo dados: produto=2692, ano=2001
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2001/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -27.0% (47/-174)
# Obtendo dados: produto=2696, ano=2001
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2001/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -27.6% (48/-174)
# Obtendo dados: produto=2713, ano=2002
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2002/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -28.2% (49/-174)
# Obtendo dados: produto=2711, ano=2002
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2002/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -28.7% (50/-174)
# Obtendo dados: produto=2702, ano=2002
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2002/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -29.3% (51/-174)
# Obtendo dados: produto=2716, ano=2002
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2002/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -29.9% (52/-174)
# Obtendo dados: produto=2692, ano=2002
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2002/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -30.5% (53/-174)
# Obtendo dados: produto=2696, ano=2002
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2002/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -31.0% (54/-174)
# Obtendo dados: produto=2713, ano=2003
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2003/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -31.6% (55/-174)
# Obtendo dados: produto=2711, ano=2003
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2003/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -32.2% (56/-174)
# Obtendo dados: produto=2702, ano=2003
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2003/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -32.8% (57/-174)
# Obtendo dados: produto=2716, ano=2003
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2003/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -33.3% (58/-174)
# Obtendo dados: produto=2692, ano=2003
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2003/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -33.9% (59/-174)
# Obtendo dados: produto=2696, ano=2003
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2003/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -34.5% (60/-174)
# Obtendo dados: produto=2713, ano=2004
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2004/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -35.1% (61/-174)
# Obtendo dados: produto=2711, ano=2004
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2004/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -35.6% (62/-174)
# Obtendo dados: produto=2702, ano=2004
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2004/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -36.2% (63/-174)
# Obtendo dados: produto=2716, ano=2004
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2004/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -36.8% (64/-174)
# Obtendo dados: produto=2692, ano=2004
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2004/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -37.4% (65/-174)
# Obtendo dados: produto=2696, ano=2004
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2004/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -37.9% (66/-174)
# Obtendo dados: produto=2713, ano=2005
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2005/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -38.5% (67/-174)
# Obtendo dados: produto=2711, ano=2005
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2005/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -39.1% (68/-174)
# Obtendo dados: produto=2702, ano=2005
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2005/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -39.7% (69/-174)
# Obtendo dados: produto=2716, ano=2005
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2005/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -40.2% (70/-174)
# Obtendo dados: produto=2692, ano=2005
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2005/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -40.8% (71/-174)
# Obtendo dados: produto=2696, ano=2005
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2005/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -41.4% (72/-174)
# Obtendo dados: produto=2713, ano=2006
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2006/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -42.0% (73/-174)
# Obtendo dados: produto=2711, ano=2006
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2006/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -42.5% (74/-174)
# Obtendo dados: produto=2702, ano=2006
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2006/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -43.1% (75/-174)
# Obtendo dados: produto=2716, ano=2006
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2006/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -43.7% (76/-174)
# Obtendo dados: produto=2692, ano=2006
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2006/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -44.3% (77/-174)
# Obtendo dados: produto=2696, ano=2006
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2006/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -44.8% (78/-174)
# Obtendo dados: produto=2713, ano=2007
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2007/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -45.4% (79/-174)
# Obtendo dados: produto=2711, ano=2007
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2007/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -46.0% (80/-174)
# Obtendo dados: produto=2702, ano=2007
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2007/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -46.6% (81/-174)
# Obtendo dados: produto=2716, ano=2007
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2007/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -47.1% (82/-174)
# Obtendo dados: produto=2692, ano=2007
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2007/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -47.7% (83/-174)
# Obtendo dados: produto=2696, ano=2007
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2007/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -48.3% (84/-174)
# Obtendo dados: produto=2713, ano=2008
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2008/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -48.9% (85/-174)
# Obtendo dados: produto=2711, ano=2008
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2008/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -49.4% (86/-174)
# Obtendo dados: produto=2702, ano=2008
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2008/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -50.0% (87/-174)
# Obtendo dados: produto=2716, ano=2008
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2008/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -50.6% (88/-174)
# Obtendo dados: produto=2692, ano=2008
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2008/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -51.1% (89/-174)
# Obtendo dados: produto=2696, ano=2008
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2008/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -51.7% (90/-174)
# Obtendo dados: produto=2713, ano=2009
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2009/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -52.3% (91/-174)
# Obtendo dados: produto=2711, ano=2009
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2009/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -52.9% (92/-174)
# Obtendo dados: produto=2702, ano=2009
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2009/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -53.4% (93/-174)
# Obtendo dados: produto=2716, ano=2009
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2009/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -54.0% (94/-174)
# Obtendo dados: produto=2692, ano=2009
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2009/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -54.6% (95/-174)
# Obtendo dados: produto=2696, ano=2009
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2009/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -55.2% (96/-174)
# Obtendo dados: produto=2713, ano=2010
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2010/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -55.7% (97/-174)
# Obtendo dados: produto=2711, ano=2010
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2010/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -56.3% (98/-174)
# Obtendo dados: produto=2702, ano=2010
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2010/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -56.9% (99/-174)
# Obtendo dados: produto=2716, ano=2010
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2010/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -57.5% (100/-174)
# Obtendo dados: produto=2692, ano=2010
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2010/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -58.0% (101/-174)
# Obtendo dados: produto=2696, ano=2010
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2010/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -58.6% (102/-174)
# Obtendo dados: produto=2713, ano=2011
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2011/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -59.2% (103/-174)
# Obtendo dados: produto=2711, ano=2011
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2011/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -59.8% (104/-174)
# Obtendo dados: produto=2702, ano=2011
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2011/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -60.3% (105/-174)
# Obtendo dados: produto=2716, ano=2011
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2011/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -60.9% (106/-174)
# Obtendo dados: produto=2692, ano=2011
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2011/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -61.5% (107/-174)
# Obtendo dados: produto=2696, ano=2011
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2011/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -62.1% (108/-174)
# Obtendo dados: produto=2713, ano=2012
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2012/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -62.6% (109/-174)
# Obtendo dados: produto=2711, ano=2012
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2012/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -63.2% (110/-174)
# Obtendo dados: produto=2702, ano=2012
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2012/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -63.8% (111/-174)
# Obtendo dados: produto=2716, ano=2012
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2012/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -64.4% (112/-174)
# Obtendo dados: produto=2692, ano=2012
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2012/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -64.9% (113/-174)
# Obtendo dados: produto=2696, ano=2012
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2012/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -65.5% (114/-174)
# Obtendo dados: produto=2713, ano=2013
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2013/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -66.1% (115/-174)
# Obtendo dados: produto=2711, ano=2013
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2013/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -66.7% (116/-174)
# Obtendo dados: produto=2702, ano=2013
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2013/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -67.2% (117/-174)
# Obtendo dados: produto=2716, ano=2013
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2013/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -67.8% (118/-174)
# Obtendo dados: produto=2692, ano=2013
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2013/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -68.4% (119/-174)
# Obtendo dados: produto=2696, ano=2013
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2013/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -69.0% (120/-174)
# Obtendo dados: produto=2713, ano=2014
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2014/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -69.5% (121/-174)
# Obtendo dados: produto=2711, ano=2014
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2014/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -70.1% (122/-174)
# Obtendo dados: produto=2702, ano=2014
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2014/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -70.7% (123/-174)
# Obtendo dados: produto=2716, ano=2014
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2014/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -71.3% (124/-174)
# Obtendo dados: produto=2692, ano=2014
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2014/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -71.8% (125/-174)
# Obtendo dados: produto=2696, ano=2014
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2014/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -72.4% (126/-174)
# Obtendo dados: produto=2713, ano=2015
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2015/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -73.0% (127/-174)
# Obtendo dados: produto=2711, ano=2015
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2015/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -73.6% (128/-174)
# Obtendo dados: produto=2702, ano=2015
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2015/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -74.1% (129/-174)
# Obtendo dados: produto=2716, ano=2015
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2015/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -74.7% (130/-174)
# Obtendo dados: produto=2692, ano=2015
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2015/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -75.3% (131/-174)
# Obtendo dados: produto=2696, ano=2015
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2015/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -75.9% (132/-174)
# Obtendo dados: produto=2713, ano=2016
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2016/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -76.4% (133/-174)
# Obtendo dados: produto=2711, ano=2016
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2016/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -77.0% (134/-174)
# Obtendo dados: produto=2702, ano=2016
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2016/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -77.6% (135/-174)
# Obtendo dados: produto=2716, ano=2016
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2016/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -78.2% (136/-174)
# Obtendo dados: produto=2692, ano=2016
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2016/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -78.7% (137/-174)
# Obtendo dados: produto=2696, ano=2016
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2016/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -79.3% (138/-174)
# Obtendo dados: produto=2713, ano=2017
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2017/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -79.9% (139/-174)
# Obtendo dados: produto=2711, ano=2017
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2017/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -80.5% (140/-174)
# Obtendo dados: produto=2702, ano=2017
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2017/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -81.0% (141/-174)
# Obtendo dados: produto=2716, ano=2017
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2017/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -81.6% (142/-174)
# Obtendo dados: produto=2692, ano=2017
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2017/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -82.2% (143/-174)
# Obtendo dados: produto=2696, ano=2017
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2017/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -82.8% (144/-174)
# Obtendo dados: produto=2713, ano=2018
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2018/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -83.3% (145/-174)
# Obtendo dados: produto=2711, ano=2018
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2018/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -83.9% (146/-174)
# Obtendo dados: produto=2702, ano=2018
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2018/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -84.5% (147/-174)
# Obtendo dados: produto=2716, ano=2018
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2018/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -85.1% (148/-174)
# Obtendo dados: produto=2692, ano=2018
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2018/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -85.6% (149/-174)
# Obtendo dados: produto=2696, ano=2018
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2018/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -86.2% (150/-174)
# Obtendo dados: produto=2713, ano=2019
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2019/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -86.8% (151/-174)
# Obtendo dados: produto=2711, ano=2019
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2019/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -87.4% (152/-174)
# Obtendo dados: produto=2702, ano=2019
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2019/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -87.9% (153/-174)
# Obtendo dados: produto=2716, ano=2019
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2019/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -88.5% (154/-174)
# Obtendo dados: produto=2692, ano=2019
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2019/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -89.1% (155/-174)
# Obtendo dados: produto=2696, ano=2019
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2019/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -89.7% (156/-174)
# Obtendo dados: produto=2713, ano=2020
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2020/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -90.2% (157/-174)
# Obtendo dados: produto=2711, ano=2020
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2020/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -90.8% (158/-174)
# Obtendo dados: produto=2702, ano=2020
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2020/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -91.4% (159/-174)
# Obtendo dados: produto=2716, ano=2020
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2020/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -92.0% (160/-174)
# Obtendo dados: produto=2692, ano=2020
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2020/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -92.5% (161/-174)
# Obtendo dados: produto=2696, ano=2020
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2020/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -93.1% (162/-174)
# Obtendo dados: produto=2713, ano=2021
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2021/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -93.7% (163/-174)
# Obtendo dados: produto=2711, ano=2021
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2021/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -94.3% (164/-174)
# Obtendo dados: produto=2702, ano=2021
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2021/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -94.8% (165/-174)
# Obtendo dados: produto=2716, ano=2021
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2021/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -95.4% (166/-174)
# Obtendo dados: produto=2692, ano=2021
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2021/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -96.0% (167/-174)
# Obtendo dados: produto=2696, ano=2021
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2021/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -96.6% (168/-174)
# Obtendo dados: produto=2713, ano=2022
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2022/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -97.1% (169/-174)
# Obtendo dados: produto=2711, ano=2022
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2022/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -97.7% (170/-174)
# Obtendo dados: produto=2702, ano=2022
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2022/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -98.3% (171/-174)
# Obtendo dados: produto=2716, ano=2022
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2022/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -98.9% (172/-174)
# Obtendo dados: produto=2692, ano=2022
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2022/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -99.4% (173/-174)
# Obtendo dados: produto=2696, ano=2022
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2022/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -100.0% (174/-174)
# Obtendo dados: produto=2713, ano=2023
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2023/c81/2713/f/u
# Obtidos 685 registros
# Progresso: -100.6% (175/-174)
# Obtendo dados: produto=2711, ano=2023
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2023/c81/2711/f/u
# Obtidos 685 registros
# Progresso: -101.1% (176/-174)
# Obtendo dados: produto=2702, ano=2023
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2023/c81/2702/f/u
# Obtidos 685 registros
# Progresso: -101.7% (177/-174)
# Obtendo dados: produto=2716, ano=2023
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2023/c81/2716/f/u
# Obtidos 685 registros
# Progresso: -102.3% (178/-174)
# Obtendo dados: produto=2692, ano=2023
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2023/c81/2692/f/u
# Obtidos 685 registros
# Progresso: -102.9% (179/-174)
# Obtendo dados: produto=2696, ano=2023
# URL: https://apisidra.ibge.gov.br/values/t/1612/n8/all/p/2023/c81/2696/f/u
# Obtidos 685 registros
# Progresso: -103.4% (180/-174)
# Unindo todos os dados...
# Dados salvos em: producao_agricola_mesorregiao.parquet
# Processamento concluído!

# %%
resultado = pd.read_parquet('producao_agricola_mesorregiao.parquet')

# %%
def processar_dados_mesorregiao_unificado(resultado, regions):
    """
    Processa dados agrícolas em nível de mesorregião em um único DataFrame consolidado.
    Elimina 'Área colhida' (pois é idêntico a Área Plantada), mantendo apenas os dados essenciais.
    """
    # Tipos que serão processados (removendo Área colhida)
    tipos_a_processar = ['Área plantada', 'Quantidade produzida', 'Rendimento médio da produção', 'Valor da produção']
    
    # Inicializar um dicionário para armazenar os DataFrames temporários
    dfs_temp = {}
    
    # Processar cada tipo de dado em um DataFrame temporário
    for tipo in tipos_a_processar:
        # Filtrar resultado pelo tipo atual
        df_temp = resultado[resultado['D4N'] == tipo].copy()
        
        # Converter e limpar valores
        df_temp.loc[:, 'V'] = df_temp['V'].replace(['...', '-', np.nan], 0)
        df_temp.loc[:, 'V'] = pd.to_numeric(df_temp['V'])
        df_temp.loc[:, 'D2N'] = pd.to_numeric(df_temp['D2N'])
        
        # Renomear colunas básicas
        df_temp = df_temp.rename(columns={
            'D2N': 'Ano',
            'D3N': 'Produto',
            'D1N': 'Mesorregião'
        })
        
        # Limpar nomes de produtos (remover texto entre parênteses)
        df_temp['Produto'] = df_temp['Produto'].apply(
            lambda x: x.split(' (')[0] if isinstance(x, str) and ' (' in x else x
        )
        
        # Definir o nome da coluna de valor baseado no tipo
        if tipo == 'Área plantada':
            novo_nome_valor = 'Area_Plantada_Hectares'
        elif tipo == 'Quantidade produzida':
            novo_nome_valor = 'Producao_Toneladas'
        elif tipo == 'Rendimento médio da produção':
            novo_nome_valor = 'Rendimento_KgPorHectare'
        elif tipo == 'Valor da produção':
            novo_nome_valor = 'Valor_Produzido_Mil_Reais'
        
        # Selecionar apenas as colunas necessárias
        df_temp = df_temp[['Mesorregião', 'Ano', 'Produto', 'V']]
        
        # Renomear a coluna de valor para o nome específico
        df_temp = df_temp.rename(columns={'V': novo_nome_valor})
        
        # Armazenar no dicionário
        dfs_temp[tipo] = df_temp
    
    # Mesclar os DataFrames usando as colunas de identificação como chaves
    # Começar com o primeiro DataFrame
    df_consolidado = dfs_temp[tipos_a_processar[0]]
    
    # Mesclar com os outros DataFrames
    for tipo in tipos_a_processar[1:]:
        df_consolidado = pd.merge(
            df_consolidado,
            dfs_temp[tipo],
            on=['Mesorregião', 'Ano', 'Produto'],
            how='outer'
        )
    
    # Preencher valores ausentes resultantes da mesclagem
    df_consolidado = df_consolidado.fillna(0)
    
    # Filtrar para manter apenas anos >= 1990 e com dados diferentes de 0
    #df_consolidado = df_consolidado[df_consolidado['Ano'] >= 1990]
    #df_consolidado = df_consolidado[~((df_consolidado['Area_Plantada_Hectares'] == 0) & (df_consolidado['Producao_Toneladas'] == 0) & (df_consolidado['Rendimento_KgPorHectare'] == 0))]
    
    # Remover os dados de Valor_Produzido_Reais de antes de 1994, pré-Real
    #df_consolidado.loc[df_consolidado['Ano'] < 1994, 'Valor_Produzido_Mil_Reais'] = 0
    
    # Salvar o DataFrame consolidado
    df_consolidado.to_parquet('dados_agricolas_mesorregiao.parquet', index=False)
    
    return df_consolidado

# Exemplo de uso:
df_consolidado = processar_dados_mesorregiao_unificado(resultado, regions)
# Out:
# C:\Users\luiz_\AppData\Local\Temp\ipykernel_10308\439264189.py:67: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_consolidado = df_consolidado.fillna(0)

# %%
df_consolidado = pd.read_parquet('dados_agricolas_mesorregiao.parquet')
df_consolidado.head(20)
# Out:
#               Mesorregião   Ano         Produto  Area_Plantada_Hectares  \
# 0   Agreste Alagoano - AL  1994           Arroz                     370
# 1   Agreste Alagoano - AL  1994  Cana-de-açúcar                   11020
# 2   Agreste Alagoano - AL  1994          Feijão                   32866
# 3   Agreste Alagoano - AL  1994           Milho                   24417
# 4   Agreste Alagoano - AL  1994            Soja                       0
# 5   Agreste Alagoano - AL  1994           Trigo                       0
# 6   Agreste Alagoano - AL  1995           Arroz                     265
# 7   Agreste Alagoano - AL  1995  Cana-de-açúcar                   11279
# 8   Agreste Alagoano - AL  1995          Feijão                   31841
# 9   Agreste Alagoano - AL  1995           Milho                   23183
# 10  Agreste Alagoano - AL  1995            Soja                       0
# 11  Agreste Alagoano - AL  1995           Trigo                       0
# 12  Agreste Alagoano - AL  1996           Arroz                     149
# 13  Agreste Alagoano - AL  1996  Cana-de-açúcar                   10858
# 14  Agreste Alagoano - AL  1996          Feijão                   32423
# 15  Agreste Alagoano - AL  1996           Milho                   23135
# 16  Agreste Alagoano - AL  1996            Soja                       0
# 17  Agreste Alagoano - AL  1996           Trigo                       0
# 18  Agreste Alagoano - AL  1997           Arroz                     148
# 19  Agreste Alagoano - AL  1997  Cana-de-açúcar                   10605
#
#     Producao_Toneladas  Rendimento_KgPorHectare  Valor_Produzido_Mil_Reais
# 0                  874                     2362                        140
# 1               539299                    48938                       9132
# 2                18194                      553                       9604
# 3                15088                      618                       1855
# 4                    0                        0                          0
# 5                    0                        0                          0
# 6                  617                     2328                        145
# 7               541014                    47966                       9998
# 8                18420                      578                       5727
# 9                14774                      637                       2049
# 10                   0                        0                          0
# 11                   0                        0                          0
# 12                 354                     2375                         64
# 13              509578                    46931                       9602
# 14               13523                      481                       6625
# 15               12714                      549                       2424
# 16                   0                        0                          0
# 17                   0                        0                          0
# 18                 230                     1554                         48
# 19              496220                    47102                      10656

# %%
rendimento = df_consolidado[['Produto', 'Ano', 'Mesorregião', 'Rendimento_KgPorHectare']].copy()

# Create dropdown widgets only once and store them as global variables
region_dropdown = widgets.Dropdown(
    options=sorted(rendimento['Mesorregião'].unique()),
    description='Região:',
    style={'description_width': 'initial'}
)

rendimento = df_consolidado[['Produto', 'Ano', 'Mesorregião', 'Rendimento_KgPorHectare']].copy()

# Dicionário com anos e tipo de fenômeno
fenomenos_climaticos = {
    1990: 'El Niño',
    1991: 'El Niño',
    1992: 'El Niño',
    1993: 'Neutro',
    1994: 'El Niño',
    1995: 'La Niña',
    1996: 'La Niña',
    1997: 'El Niño',
    1998: 'La Niña',
    1999: 'La Niña',
    2000: 'La Niña',
    2001: 'Neutro',
    2002: 'El Niño',
    2003: 'Neutro',
    2004: 'El Niño',
    2005: 'Neutro',
    2006: 'El Niño',
    2007: 'La Niña',
    2008: 'La Niña',
    2009: 'El Niño',
    2010: 'La Niña',
    2011: 'La Niña',
    2012: 'La Niña',
    2013: 'Neutro',
    2014: 'Neutro',
    2015: 'El Niño',
    2016: 'El Niño',
    2017: 'Neutro',
    2018: 'El Niño',
    2019: 'Neutro',
    2020: 'La Niña',
    2021: 'La Niña',
    2022: 'La Niña'
}

# Cores para cada fenômeno
cores_fenomenos = {
    'El Niño': 'rgba(255, 100, 100, 0.2)',  # vermelho claro
    'La Niña': 'rgba(100, 100, 255, 0.2)',  # azul claro
    'Neutro': 'rgba(200, 200, 200, 0.2)'    # cinza claro
}

def update_plot(region):
    filtered_data = rendimento[rendimento['Mesorregião'] == region]

    fig = go.Figure()

    for produto in filtered_data['Produto'].unique():
        df_produto = filtered_data[filtered_data['Produto'] == produto]
        fig.add_trace(go.Scatter(
            x=df_produto['Ano'],
            y=df_produto['Rendimento_KgPorHectare'],
            mode='lines+markers',
            name=produto
        ))

    # Adiciona faixas coloridas no fundo para El Niño / La Niña / Neutro
    for ano, fenomeno in fenomenos_climaticos.items():
        fig.add_shape(
            type='rect',
            x0=ano - 0.5,  # início do ano
            x1=ano + 0.5,  # fim do ano
            y0=0,
            y1=1,
            xref='x',
            yref='paper',
            fillcolor=cores_fenomenos.get(fenomeno, 'rgba(0,0,0,0)'),
            layer='below',
            line_width=0
        )

    fig.update_layout(
        title=f'Rendimento anual em {region}',
        xaxis_title='Ano',
        yaxis_title='Rendimento (Kg/ha)',
        yaxis=dict(rangemode='tozero'),
        legend_title='Produto'
    )

    fig.show()

# Create the interactive plot without creating new dropdowns
interactive_plot = widgets.interactive(update_plot, region=region_dropdown)

# Display the interactive plot
display(interactive_plot)
# Out:
# interactive(children=(Dropdown(description='Região:', options=('Agreste Alagoano - AL', 'Agreste Paraibano - P…

# %%
# Group by Year and Product first, then get top 5 producers for each combination
ranking = df_consolidado[['Produto', 'Ano', 'Mesorregião', 'Producao_Toneladas']].copy()
ranking = ranking.rename(columns={'Producao_Toneladas': 'Produção'})

# Sort within each group and get top 5
ranking = (ranking.groupby(['Ano', 'Produto'])
          .apply(lambda x: x.nlargest(5, 'Produção'))
          .reset_index(drop=True))

# Sort by Product, Year for better visualization
ranking = ranking.sort_values(['Produto', 'Ano', 'Produção'], ascending=[True, True, False])
ranking = ranking.reset_index(drop=True)
ranking
# Out:
# C:\Users\luiz_\AppData\Local\Temp\ipykernel_10308\4081464389.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.nlargest(5, 'Produção'))
#     Produto   Ano                          Mesorregião  Produção
# 0     Arroz  1994          Sudoeste Rio-grandense - RS   1603202
# 1     Arroz  1994           Sudeste Rio-grandense - RS   1090318
# 2     Arroz  1994   Metropolitana de Porto Alegre - RS    837786
# 3     Arroz  1994            Norte Mato-grossense - MT    482526
# 4     Arroz  1994  Centro Ocidental Rio-grandense - RS    399959
# ..      ...   ...                                  ...       ...
# 895   Trigo  2023          Noroeste Rio-grandense - RS   1822408
# 896   Trigo  2023        Norte Central Paranaense - PR    711425
# 897   Trigo  2023             Sudoeste Paranaense - PR    592971
# 898   Trigo  2023      Centro Oriental Paranaense - PR    491083
# 899   Trigo  2023       Norte Pioneiro Paranaense - PR    460939
#
# [900 rows x 4 columns]

# %%
rendimento_medio = rendimento.groupby(['Produto', 'Ano']).agg({'Rendimento_KgPorHectare': 'mean'}).reset_index()

def update_plot():
    fig = go.Figure()

    # Add lines for each product
    for produto in rendimento_medio['Produto'].unique():
        df_produto = rendimento_medio[rendimento_medio['Produto'] == produto]
        fig.add_trace(go.Scatter(
            x=df_produto['Ano'],
            y=df_produto['Rendimento_KgPorHectare'],
            mode='lines+markers',
            name=produto,
            line=dict(width=2),
            marker=dict(size=6)
        ))

    # Update layout with better formatting
    fig.update_layout(
        title=dict(
            text='Rendimento Médio das Culturas (1990-2022)',
            x=0.5,
            font=dict(size=20)
        ),
        xaxis=dict(
            title='Ano',
            gridcolor='lightgray',
            showgrid=True
        ),
        yaxis=dict(
            title='Rendimento (Kg/ha)',
            gridcolor='lightgray',
            showgrid=True,
            rangemode='tozero'
        ),
        legend=dict(
            title='Culturas',
            yanchor="top",
            y=0.99,
            xanchor="left",
            x=1.02
        ),
        showlegend=True,
        plot_bgcolor='white',
        hovermode='x unified',
        width=1000,
        height=600
    )

    fig.show()

# Create and display the interactive plot
interactive_plot = widgets.interactive(update_plot)
display(interactive_plot)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 rendimento_medio = rendimento.groupby(['Produto', 'Ano']).agg({'Rendimento_KgPorHectare': 'mean'}).reset_index()
#       3 def update_plot():
#       4     fig = go.Figure()
#
# NameError: name 'rendimento' is not defined

# %%
df_consolidado[['Area_Plantada_Hectares', 'Rendimento_KgPorHectare', 'Valor_Produzido_Mil_Reais']].corr()
# Out:
#                            Area_Plantada_Hectares  Rendimento_KgPorHectare  \
# Area_Plantada_Hectares                   1.000000                 0.158059
# Rendimento_KgPorHectare                  0.158059                 1.000000
# Valor_Produzido_Mil_Reais                0.757416                 0.161900
#
#                            Valor_Produzido_Mil_Reais
# Area_Plantada_Hectares                      0.757416
# Rendimento_KgPorHectare                     0.161900
# Valor_Produzido_Mil_Reais                   1.000000

# %%
#   - Coeficiente de variação do rendimento por cultura e região
df_consolidado[['Produto', 'Mesorregião', 'Rendimento_KgPorHectare']].groupby(['Produto', 'Mesorregião']).agg(
    Rendimento_Medio=('Rendimento_KgPorHectare', 'mean'),
    Rendimento_Desvio=('Rendimento_KgPorHectare', 'std')
).reset_index().assign(
    Coeficiente_Variacao=lambda x: x['Rendimento_Desvio'] / x['Rendimento_Medio'] * 100
).sort_values(['Produto', 'Coeficiente_Variacao'], ascending=[True, False]).reset_index(drop=True)
# Out:
#     Produto                      Mesorregião  Rendimento_Medio  \
# 0     Arroz              Leste Potiguar - RN        173.333333
# 1     Arroz              Mata Paraibana - PB        425.133333
# 2     Arroz             Sertão Alagoano - AL        333.333333
# 3     Arroz  Metropolitana de São Paulo - SP        236.766667
# 4     Arroz           Mata Pernambucana - PE        368.866667
# ..      ...                              ...               ...
# 817   Trigo                Vale do Acre - AC          0.000000
# 818   Trigo               Vale do Juruá - AC          0.000000
# 819   Trigo              Vale do Mucuri - MG          0.000000
# 820   Trigo            Vale do Rio Doce - MG          0.000000
# 821   Trigo                Zona da Mata - MG          0.000000
#
#      Rendimento_Desvio  Coeficiente_Variacao
# 0           659.641142            380.562198
# 1          1302.852407            306.457364
# 2           864.364759            259.309428
# 3           498.638538            210.603353
# 4           745.600371            202.132759
# ..                 ...                   ...
# 817           0.000000                   NaN
# 818           0.000000                   NaN
# 819           0.000000                   NaN
# 820           0.000000                   NaN
# 821           0.000000                   NaN
#
# [822 rows x 5 columns]

# %%
meteo = pd.read_csv('meteo.csv.gz', compression='gzip')

cod_muni = pd.read_csv('cod_muni.csv.gz', compression='gzip')
cod_muni['Mesorregião'] = cod_muni['nome_mesorregiao'] + ' - ' + cod_muni['sigla_uf']
cod_muni=cod_muni[['id_municipio', 'Mesorregião']]

meteo=meteo.merge(cod_muni, on='id_municipio', how='left')
meteo = meteo[['id_estacao', "Mesorregião"]]

# %% [markdown]
# Dados meteorológicos baixados do BDMEP através do BigQuery com a seguinte query para já agregar os dados (originalmente em hora) e reduzir o tamanho do arquivo
#
#
#     SELECT
#     ano,
#     id_estacao,
#     SUM(precipitacao_total) AS precipitacao_total_anual,
#     AVG(radiacao_global) AS radiacao_global_media,
#     AVG(temperatura_bulbo_hora) AS temperatura_bulbo_media,
#     AVG(vento_velocidade) AS vento_velocidade_media
#
#     FROM
#       basedosdados.br_inmet_bdmep.microdados
#
#     GROUP BY
#       ano, id_estacao
#
#     ORDER BY
#       ano, id_estacao

# %%
dados_meteo = pd.read_csv('dados_meteo.csv').rename(columns={'ano': 'Ano'})
dados_meteo = dados_meteo.merge(meteo, on='id_estacao', how='left').drop(columns=['id_estacao'])

# %%
df_meteo = df_consolidado.merge(dados_meteo, on=['Mesorregião', 'Ano'], how='left')

# %%
df_meteo.columns
# Out:
# Index(['Mesorregião', 'Ano', 'Produto', 'Area_Plantada_Hectares',
#        'Producao_Toneladas', 'Rendimento_KgPorHectare',
#        'Valor_Produzido_Mil_Reais', 'precipitacao_total_anual',
#        'radiacao_global_media', 'temperatura_bulbo_media',
#        'vento_velocidade_media'],
#       dtype='object')

# %%
df_meteo.corr(numeric_only=True)
df_meteo.to_parquet('dados_meteo.parquet', index=False)

# %% [markdown]
# Análises a se incluir no dashboard:
#
# 1. **Análise de tendências temporais**:
#    - Gráficos de linha mostrando a evolução do rendimento médio de cada cultura ao longo do tempo
#    - Identificação de pontos de inflexão (anos com mudanças significativas)
#
# 2. **Comparativos regionais**:
#    - Ranking das mesorregiões mais produtivas para cada cultura
#    - Mapas de calor mostrando a distribuição espacial da produtividade
#
# 3. **Correlações entre variáveis**:
#    - Relação entre área plantada e rendimento (verificar se há economias de escala)
#    - Correlação entre valor da produção e rendimento
#
# 4. **Análise de volatilidade**:
#    - Coeficiente de variação do rendimento por cultura e região
#    - Identificação das regiões e culturas mais estáveis/instáveis
#
# 5. **Taxonomia de mesorregiões**:
#    - Agrupamento de regiões com padrões similares de produtividade
#    - Classificação por perfil de culturas predominantes
#
# 6. **Séries temporais avançadas**:
#    - Decomposição das séries (tendência, sazonalidade, resíduos)
#    - Detecção de outliers e eventos extremos
#
# 7. **Indicadores de especialização regional**:
#    - Índice de concentração para identificar especialização por cultura
#    - Evolução da diversificação agrícola nas mesorregiões
#
# 8. **Visualizações interativas**:
#    - Filtros por cultura, período e região
#    - Animações mostrando mudanças espaciais ao longo do tempo
#
# Estas análises fornecerão uma base sólida para, posteriormente, integrar os dados climáticos e identificar correlações com os padrões de produtividade.

# %%
df = pd.read_parquet('dados_meteo.parquet')
